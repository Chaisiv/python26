# %%
number = 11
if number % 2 == 0:
    print ("even")
else:
    print("odd")
# Out:
# odd

# %%
number = -29
if number > 0:
    print ("number is positive")
    print("this is for fun")
if number < 10:
    print ("number is negative")
print ("i am done")
# Out:
# number is negative
# i am done

# %%
number = 1
if number < 0:
    print ("number is positive")
if number > 0:
    print ("number is negative")
if number == 0:
     print ("number is common")
# Out:
# number is negative
